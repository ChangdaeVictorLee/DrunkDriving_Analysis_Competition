# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('df_finn(ex).csv', encoding='cp949', index_col=0)

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

# %%
df[['x','y','아침','새벽','도로환경','밤','낮','도로환경','월']]

# %%
df[['x','y']]
# Out:
#                  x          y
# 0       127.298872  36.489101
# 1       127.058056  36.923056
# 2       127.382337  36.336437
# 3       127.128056  36.787778
# 4       127.057063  36.774519
# ...            ...        ...
# 100070  127.273611  36.435000
# 100071  127.376396  36.350271
# 100072  127.370828  36.309233
# 100073  127.221604  36.773741
# 100074  126.766477  36.701374
#
# [100075 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

# %%
df = df[df["사건"]==1]

# %%
df.reset_index(inplace=True)

# %%
coordinates = []
for i in range(len(df)):
    coordinates.append([df['y'][i], df['x'][i]])

# %%
coordinates[0]
# Out:
# [36.48910081, 127.2988721]

# %% [markdown]
# # k means 클러스터링

# %% [markdown]
# #### 클러스터 5

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(coordinates)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 클러스터 10

# %%
kmeans = KMeans(n_clusters=10)
kmeans.fit(coordinates)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 클러스터 15

# %%
kmeans = KMeans(n_clusters=15)
kmeans.fit(coordinates)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 클러스터 20

# %%
kmeans = KMeans(n_clusters=20)
kmeans.fit(coordinates)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 도시별 클러스터

# %%
df.대분류.unique()
# Out:
# array(['세종특별자치시', '충청남도', '대전광역시'], dtype=object)

# %%
df.중분류.unique()
# Out:
# array(['소담동', '아산시', '천안시', '논산시', '서구', '유성구', '당진시', '계룡시', '새롬동',
#        '공주시', '보령시', '서산시', '예산군', '동구', '금남면', '중구', '대덕구', '금산군', '홍성군',
#        '반곡동', '고운동', '보람동', '서천군', '부여군', '조치원읍', '세종동', '태안군', '장군면',
#        '대평동', '어진동', '한솔동', '종촌동', '도담동', '가람동', '다정동', '부강면', '연서면',
#        '청양군', '연기면', '소정면', '아름동', '나성동', '산울동', '연동면', '전의면', '누리동',
#        '해밀동', '전동면', '한별동', '집현동', '용호동', '합강동'], dtype=object)

# %% [markdown]
# #### 대전 클러스터

# %%
df_daejeon = df[df["대분류"] == "대전광역시"]

df_daejeon.reset_index(inplace=True)

coordinate = []
for i in range(len(df_daejeon)):
    coordinate.append([df_daejeon['y'][i], df_daejeon['x'][i]])

kmeans = KMeans(n_clusters=20)
kmeans.fit(coordinate)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=11)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 세종 클러스터

# %%
df_sejong = df[df["대분류"] == "세종특별자치시"]

df_sejong.reset_index(inplace=True)

coordinate = []
for i in range(len(df_sejong)):
    coordinate.append([df_sejong['y'][i], df_sejong['x'][i]])

kmeans = KMeans(n_clusters=15)
kmeans.fit(coordinate)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=11)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 천안 클러스터

# %%
df_cheong = df[df["중분류"] == "천안시"]

df_cheong.reset_index(inplace=True)

coordinate = []
for i in range(len(df_cheong)):
    coordinate.append([df_cheong['y'][i], df_cheong['x'][i]])

kmeans = KMeans(n_clusters=10)
kmeans.fit(coordinate)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 보령 클러스터

# %%
df_bo = df[df["중분류"] == "보령시"]

df_bo.reset_index(inplace=True)

coordinate = []
for i in range(len(df_bo)):
    coordinate.append([df_bo['y'][i], df_bo['x'][i]])

kmeans = KMeans(n_clusters=3)
kmeans.fit(coordinate)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 서산 클러스터

# %%
df_tae = df[df["중분류"] == "서산시"]

df_tae.reset_index(inplace=True)

coordinate = []
for i in range(len(df_tae)):
    coordinate.append([df_tae['y'][i], df_tae['x'][i]])

kmeans = KMeans(n_clusters=3)
kmeans.fit(coordinate)
labels = kmeans.labels_

centers = kmeans.cluster_centers_

centers = centers.tolist()

m = folium.Map(location=[36.489101,127.298872], zoom_start=10)

for i in centers:
    folium.Marker(location=i).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
